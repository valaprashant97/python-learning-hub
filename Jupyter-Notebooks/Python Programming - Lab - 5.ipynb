# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h2>Python Programming - 2301CS404</b></center>
# <center><b><h2>Lab - 5</b></center>
# <center><b><h3>Roll No.: 150</b></center>
# <center><b><h3>Name: Vala Prashant</b></center>
# <pre>

# %% [markdown]
# ### 1) Character Category Counter
# **Problem:** Count uppercase, lowercase, digits, and special characters in a string.
#
# **Sample Inputs & Outputs:**
# - Input: `Python3@Lab` → Uppercase: 2, Lowercase: 7, Digits: 1, Special: 1
# - Input: `HELLO123` → Uppercase: 5, Lowercase: 0, Digits: 3, Special: 0
# - Input: `hi@#9` → Uppercase: 0, Lowercase: 2, Digits: 1, Special: 2

# %%
s = input("Enter a string: ")

upper = lower = digit = special = 0

for ch in s:
    if ch.isupper():
        upper += 1
    elif ch.islower():
        lower += 1
    elif ch.isdigit():
        digit += 1
    else:
        special += 1

print("Uppercase :", upper)
print("Lowercase :", lower)
print("Digits:", digit)
print("Special characters:", special)

# %% [markdown]
# ### 2) Reverse Each Word
# - Input: `Python is Easy` → `nohtyP si ysaE`
# - Input: `Hello World` → `olleH dlroW`
# - Input: `Learn Python Fast` → `nraeL nohtyP tsaF`

# %%
s = input("Enter a string: ")

word = ""
result = ""

for ch in s:
    if ch != " ":
        word = ch + word
    else:
        result = result + word + " "
        word = ""

result = result + word

print(result)
# Out:
# Enter a string:  vala prashant
# alav tnahsarp

# %% [markdown]
# ### 3) Case Pattern Identifier
# - `PYTHON` → Uppercase
# - `python` → Lowercase
# - `Python Programming` → Title Case

# %%
s = input("Enter a string: ")

if s.isupper():
    print("Uppercase")
elif s.islower():
    print("Lowercase")
elif s.istitle():
    print("Title Case")
else:
    print("Mixed Case")

# %% [markdown]
# ### 4) First and Last Occurrence Finder
# - `programming`, `g` → First:3 Last:10
# - `banana`, `a` → First:1 Last:5
# - `hello`, `z` → Not found

# %%
s = input("Enter string: ")
ch = input("Enter character: ")
first = -1
last = -1
for i in range(len(s)):
    if s[i] == ch:
        if first == -1:
            first = i
        last = i

if first == -1:
    print("Not found")
else:
    print(f"First:{first} Last: {last}")
# Out:
# Enter string:  programming
# Enter character:  g
# First:3 Last: 10

# %% [markdown]
# ### 5) Word Frequency Counter (ignore the case)
# - `Python is easy and Python is powerful` → python: 2
# - `Java is popular but java is verbose` → java: 2
# - `C is fast` → c:1

# %%
s = input("Enter string: ")
ch = input("Enter word: ")
s = s.lower()
ch = ch.lower()
words = s.split()
count = 0
for i in range(len(words)):
    if words[i] == ch:
        count += 1
if count == 0:
    print("Not found")
else:
    print(f"{ch}: {count}")

# %% [markdown]
# ### 6) Remove Extra Spaces
# - `  Python   is   fun  ` → `Python is fun`
# - `   Hello   World ` → `Hello World`
# - `NoExtraSpace` → `NoExtraSpace`

# %%
s = input("Enter string: ")

print(" ".join(s.split()))
# Out:
# Enter string:      vallap    prashant
# vallap prashant

# %% [markdown]
# ### 7) Prefix and Suffix Removal
# - `unhappy.txt` → `happy`
# - `pretest.py` → `test`
# - `unwanted.doc` → `wanted`

# %%
s1 = input("Enter a World : ")
pre = input("Enter a prefix you remove :")
suf = input("Enter a suffix you remove :")
s2=s1.removeprefix(pre).removesuffix(suf)
print(s2)
# Out:
# Enter a World :  vala
# Enter a prefix you remove : v
# Enter a suffix you remove : a
# al

# %% [markdown]
# ### 8) Replace Vowels
# - `Programming` → `Pr*gr*mm*ng`
# - `Education` → `*d*c*t**n`
# - `Sky` → `Sky`

# %%
# s = input("Enter a string: ")
# result = ""

# for i in s:
#     if i == 'a' or i == 'e' or i == 'i' or i == 'o' or i == 'u':
#         result = result + '*'
#     else:
#         result = result + i

# print(result)

s=input("Enter a String :")
s1=s.lower()
s2=s1.replace('a','*').replace('e','*').replace('i','*').replace('o','*').replace('u','*')
print(s2)
# Out:
# Enter a String : vala
# v*l*

# %% [markdown]
# ### 9) String Compression
# - `aaabbcccc` → `a3b2c4`
# - `xxxyyyz` → `x3y3z1`
# - `abcd` → `a1b1c1d1`

# %%
# aaabb = a3b2
#  aabbaa = a2b2a2
s = input("Enter a string: ")
compressed = ""
count = 1
for i in range(len(s)):
    if i < len(s) - 1 and s[i] == s[i + 1]:
        count += 1
    else:
        compressed += s[i] + str(count)
        count = 1
print(compressed)
# Out:
# Enter a string:  ssssaaaadddd
# s4a4d4

# %% [markdown]
# ### 10) Toggle Case (without using str.swapcase())
# - `PyThOn` → `pYtHoN`
# - `HELlo` → `helLO`
# - `Python` → `pYTHON`

# %%
s = input("Enter a string: ")
s1 = ""
for ch in s:
    if ch.isupper():
        s1 += ch.lower()
    elif ch.islower():
        s1 += ch.upper()
    else:
        s1 += ch
print(s1)
# Out:
# Enter a string:  vala
# VALA

# %% [markdown]
# ### 11) Username Validation
# #### valid username rules:
# 1. only alphabets and digits
# 2. does not start with a digit
# 3. length ≥ 6
#
# - `User123` → Valid
# - `123User` → Invalid
# - `Us@12` → Invalid

# %%
username = input("Enter a username: ")
if len(username) < 6:
    print("Invalid")
elif username[0].isdigit():
    print("Invalid")
elif not username.isalnum():
    print("Invalid")
else:
    print("Valid")
# Out:
# Enter a username:  vala
# Invalid

# %% [markdown]
# ### 12) Palindrome Checker (ignore the case)
# - `Madam` → Palindrome
# - `Level` → Palindrome
# - `Python` → Not Palindrome

# %%
s = input("Enter a string: ")
if s.lower() == s.lower()[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Enter a string:  valav
# Palindrome

# %% [markdown]
# ### 13) Longest Word Finder
# - `Python programming is interesting` → programming
# - `I love coding` → coding
# - `Data structures and algorithms` → structures

# %%
sentence = input("Enter a sentence: ")
words = sentence.split()
longest = max(words, key=len)
print(longest)
# Out:
# Enter a sentence:  vala prashant maheshbhai
# maheshbhai

# %% [markdown]
# ### 14) Case Conversion
# - `python programming`
#   - Upper: PYTHON PROGRAMMING
#   - Lower: python programming
#   - Title: Python Programming
#   - Capitalize: Python programming

# %%
s = input("Enter a string: ")

print("Upper:", s.upper())
print("Lower:", s.lower())
print("Title:", s.title())
print("Capitalize:", s.capitalize())
# Out:
# Enter a string:  vala
# Upper: VALA
# Lower: vala
# Title: Vala
# Capitalize: Vala

# %% [markdown]
# ### 15) Custom Split
# - `apple,banana,grape`
# - `10|20|30`
# - `A-B-C-D`

# %%
s = input("Enter a string: ")
sym = input("Enter the symbol: ")
print(sym.join(s.split()))
# Out:
# Enter a string:  vala pra
# Enter the symbol:  |
# vala|pra
