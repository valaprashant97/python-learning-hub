# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 10</b></center>
# <center><b><h3>Roll No :150 </b></center>
# <center><b><h3>Name : Vala Prashant </b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to read and display the contents of a text file. (also try to open the file in some other directory)
# #### - in the form of a string
# #### - line by line
# #### - in the form of a list

# %%
fp=open("demo1.txt","r")
data= fp.read()
print(data)
fp.close()

file = open("D:\DBMS-2\lab-8\lab-8.txt", "rb")
print(file.read())
file.close()

file = open("demo1.txt", "r")
for line in file:
    print(line, end="") 
file.close()

print(end='\n')

file = open("demo1.txt", "r")
lines = file.readlines()
print(lines)
file.close()
# Out:
# This is demo1 file.
# Hello from students.
# this file is txt file.
# python is very easy programming language.
# This is demo1 file.
# Hello from students.
# this file is txt file.
# python is very easy programming language.
# ['This is demo1 file.\n', 'Hello from students.\n', 'this file is txt file.\n', 'python is very easy programming language.']

# %% [markdown]
# ### 02) WAP to create file named "new.txt" only if it doesn't exist.

# %%
fp= open("new.txt","w")
print("File 'new.txt' created successfully.")
fp.close()
# Out:
# File 'new.txt' created successfully.

# %% [markdown]
# ### 03) WAP to read first 5 lines from the text file.

# %%
file = open("new.txt", "r")

for i in range(5):
    line = file.readline()
    print(line, end="")

file.close()
# Out:
# jainish
# jay
# jeet
# jeel
# veer

# %% [markdown]
# ### 04) WAP to find the longest word(s) in a file.

# %%
file = open("demo1.txt", "r")

words = file.read().split()
file.close()

max_len = 0
longest_words = []

for word in words:
    if len(word) > max_len:
        max_len = len(word)
        longest_words = [word]
    elif len(word) == max_len:
        longest_words.append(word)

print("Longest word length:", max_len)
print("Longest word(s):", longest_words)
# Out:
# Longest word length: 11
# Longest word(s): ['programming']

# %% [markdown]
# ### 05) WAP to count the no. of lines, words and characters in a given text file.

# %%
file = open("demo1.txt", "r")

lines = file.readlines()
file.close()

line_count = len(lines)
word_count = 0
char_count = 0

for line in lines:
    word_count += len(line.split())
    char_count += len(line)

print("Number of lines:", line_count)
print("Number of words:", word_count)
print("Number of characters:", char_count)
# Out:
# Number of lines: 4
# Number of words: 18
# Number of characters: 105

# %% [markdown]
# ### 06) WAP to copy the content of a file to the another file.

# %%
fp1= open("demo1.txt","r")
fp2= open("new.txt","w")

fp2.write(fp1.read())

fp1.close()
fp2.close()
print("File copied successfully.")
# Out:
# File copied successfully.

# %% [markdown]
# ### 07) WAP to find the size of the text file.

# %%
file = open("demo1.txt", "r")

file.seek(0, 2)
size = file.tell()

file.close()
print("Size of file:", size, "bytes")
# Out:
# Size of file: 105 bytes

# %% [markdown]
# ### 08) WAP to create an UDF named frequency to count occurances of the specific word in a given text file.

# %%
def frequency(name):
    count = 0
    fp = open("demo1.txt", "r")
    words = fp.read().lower().split()

    for i in words:
        if i == name.lower():
            count += 1

    fp.close()
    return count
print("Frequency:", frequency("file"))
# Out:
# Frequency: 1

# %% [markdown]
# ### 09) WAP to get the score of five subjects from the user, store them in a file. Fetch those marks and find the highest score.

# %%
file = open("marks.txt", "w")

for i in range(1, 6):
    marks = int(input(f"Enter marks of subject {i}: "))
    file.write(str(marks) + "\n")

file.close()

with open("marks.txt", "r") as file:
    print("Highest score:", max(map(int, file)))
# Out:
# Enter marks of subject 1:  50
# Enter marks of subject 2:  60
# Enter marks of subject 3:  55
# Enter marks of subject 4:  80
# Enter marks of subject 5:  99
# Highest score: 99

# %% [markdown]
# ### 10) WAP to write first 100 prime numbers to a file named primenumbers.txt
# (Note: each number should be in new line)

# %%
file = open("primenumbers.txt", "w")

count = 0
num = 2

while count < 100:
    is_prime = True

    for i in range(2, int(num ** 0.5) + 1):
        if num % i == 0:
            is_prime = False
            break

    if is_prime:
        file.write(str(num) + "\n")
        count += 1

    num += 1

file.close()

print("First 100 prime numbers written to primenumbers.txt")
# Out:
# First 100 prime numbers written to primenumbers.txt

# %% [markdown]
# ### 11) WAP to merge two files and write it in a new file.

# %%
file1 = open("new.txt", "r")
file2 = open("demo1.txt", "r")
file3 = open("merged.txt", "w")

file3.write(file1.read())
file3.write(file2.read())

file1.close()
file2.close()
file3.close()

print("Files merged successfully.")
# Out:
# Files merged successfully.

# %% [markdown]
# ### 12) WAP to replace word1 by word2 of a text file. Write the updated data to new file.

# %%
file1 = open("demo1.txt", "r")
data = file1.read()
file1.close()

data = data.replace("file", "filess")

file2 = open("updated.txt", "w")
file2.write(data)
file2.close()

print("Word replaced and data written to new file.")
# Out:
# Word replaced and data written to new file.

# %% [markdown]
# ### 13) Demonstrate tell() and seek() for all the cases(seek from beginning-end-current position) taking a suitable example of your choice.

# %%
file = open("demo1.txt", "rb")

print("Initial position:", file.tell())

file.seek(6, 0)
print("After seek(6, 0):", file.tell())
print("Character:", file.read(1).decode())

file.seek(2, 1)
print("After seek(2, 1):", file.tell())
print("Character:", file.read(1).decode())

file.seek(-5, 2)
print("After seek(-5, 2):", file.tell())
print("Character:", file.read(1).decode())

file.close()
# Out:
# Initial position: 0
# After seek(6, 0): 6
# Character: s
# After seek(2, 1): 9
# Character: e
# After seek(-5, 2): 100
# Character: u
