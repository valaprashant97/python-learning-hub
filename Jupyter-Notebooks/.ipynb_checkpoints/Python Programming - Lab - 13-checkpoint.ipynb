# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h2>Python Programming - 2301CS404</b></center>
# <center><b><h2>Lab - 13</b></center>
# <center><b><h3>Roll No.: 150</b></center>
# <center><b><h3>Name: Vala Prashant</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to create Calculator module which defines functions like add, sub,mul and div.
# ### Create another .py file that uses the functions available in Calculator module.

# %%
import calculator

a = float(input("Enter first number: "))
b = float(input("Enter second number: "))

print("Add:", calculator.add(a, b))
print("Sub:", calculator.sub(a, b))
print("Mul:", calculator.mul(a, b))
print("Div:", calculator.div(a, b))
# Out:
# Enter first number:  10
# Enter second number:  10
# Add: 20.0
# Sub: 0.0
# Mul: 100.0
# Div: 1.0

# %% [markdown]
# ### 02) WAP to pick a random character from a given String.

# %%
import random

s = input("Enter a string: ")
ch = random.choice(s)

print("Random character:", ch)
# Out:
# Enter a string:  ddsadsad
# Random character: a

# %% [markdown]
# ### 03) WAP to pick a random element from a given list.

# %% [markdown]
# ### 04) WAP to roll a dice in such a way that every time you get the same number.

# %%
import random

lst = input("Enter list elements (separated by space ) : ").split()
element = random.choice(lst)

print("Random element:", element)
# Out:
# Enter list elements (separated by space ) :  2 2 2 3 3  4 4
# Random element: 2

# %% [markdown]
# ### 05) WAP to generate 3 random integers between 100 and 999 which is divisible by 5.

# %% [markdown]
# ### 06) WAP to generate 100 random lottery tickets and pick two lucky tickets from it and announce them as Winner and Runner up respectively.

# %%
import random

nums = []

while len(nums) < 3:
    n = random.randint(100, 999)
    if n % 5 == 0:
        nums.append(n)

print(nums)
# Out:
# [975, 660, 105]

# %% [markdown]
# ### 07) WAP to print current date and time in Python.

# %%
from datetime import datetime

now = datetime.now()

print("Current date and time:", now)
# Out:
# Current date and time: 2026-03-24 01:36:43.520333

# %% [markdown]
# ### 08) Subtract a week (7 days) from a given date in Python.

# %%
from datetime import datetime, timedelta

date_str = input("Enter date (YYYY-MM-DD): ")
d = datetime.strptime(date_str, "%Y-%m-%d")

new_date = d - timedelta(days=7)

print("New date:", new_date.date())
# Out:
# Enter date (YYYY-MM-DD):  2007-05-28
# New date: 2007-05-21

# %% [markdown]
# ### 09) WAP to Calculate number of days between two given dates.

# %%
from datetime import datetime

d1 = input("Enter first date (YYYY-MM-DD): ")
d2 = input("Enter second date (YYYY-MM-DD): ")

date1 = datetime.strptime(d1, "%Y-%m-%d")
date2 = datetime.strptime(d2, "%Y-%m-%d")

days = abs((date2 - date1).days)

print("Number of days:", days)
# Out:
# Enter first date (YYYY-MM-DD):  2007-05-28
# Enter second date (YYYY-MM-DD):  2026-05-28
# Number of days: 6940

# %% [markdown]
# ### 10) WAP to Find the day of the week of a given date.(i.e. wether it is sunday/monday/tuesday/etc.)

# %%
from datetime import datetime

date_str = input("Enter date (YYYY-MM-DD): ")
d = datetime.strptime(date_str, "%Y-%m-%d")

print("Day:", d.strftime("%A"))
# Out:
# Enter date (YYYY-MM-DD):  2026-05-28
# Day: Thursday
