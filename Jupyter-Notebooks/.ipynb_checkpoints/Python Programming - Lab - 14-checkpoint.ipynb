# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h2>Python Programming - 2301CS404</b></center>
# <center><b><h2>Lab - 14</b></center>
# <center><b><h3>Roll No.: 150</b></center>
# <center><b><h3>Name: Vala Prashant</b></center>
# <pre>

# %% [markdown]
# ## Import matplotlib below

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp314-cp314-win_amd64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.0-cp314-cp314-win_amd64.whl.metadata (119 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp314-cp314-win_amd64.whl.metadata (5.2 kB)
# Collecting numpy>=1.23 (from matplotlib)
#   Downloading numpy-2.4.3-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.1-cp314-cp314-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp314-cp314-win_amd64.whl (8.3 MB)
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ------------ --------------------------- 2.6/8.3 MB 15.3 MB/s eta 0:00:01
#    ------------------------------- -------- 6.6/8.3 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 18.6 MB/s  0:00:00
# Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl (232 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.0-cp314-cp314-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 18.7 MB/s  0:00:00
# Downloading kiwisolver-1.5.0-cp314-cp314-win_amd64.whl (75 kB)
# Downloading numpy-2.4.3-cp314-cp314-win_amd64.whl (12.4 MB)
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ----------------- ---------------------- 5.5/12.4 MB 26.1 MB/s eta 0:00:01
#    -------------------------------- ------- 10.2/12.4 MB 24.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 22.6 MB/s  0:00:00
# Downloading pillow-12.1.1-cp314-cp314-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ----------------------- ---------------- 4.2/7.2 MB 20.9 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 21.5 MB/s  0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/8 [pyparsing]
#    ---------------------------------------- 0/8 [pyparsing]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    ------------------------------ --------- 6/8 [contourpy]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ---------------------------------------- 8/8 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.0 kiwisolver-1.5.0 matplotlib-3.10.8 numpy-2.4.3 pillow-12.1.1 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### 01) WAP to display the line chart for given data for x and y axis.

# %%
x = range(1,11)
y = [1,5,9,7,5,6,3,2,4,9]

# %%
import matplotlib.pyplot as plt
x = range(1, 11)
y = [1,5,9,7,5,6,3,2,4,9]
plt.plot(x, y, marker='o')
plt.title("line chart")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# ### 02) WAP to generate line chart for given data.

# %%
x = range(1,11,1)
cxMarks= [8,9,6,3,5,7,4,1,2,6]
cyMarks= [5,8,9,6,3,2,4,8,8,9]

# %%
import matplotlib.pyplot as plt
x = range(1,11,1)
cxMarks= [8,9,6,3,5,7,4,1,2,6]
cyMarks= [5,8,9,6,3,2,4,8,8,9]
plt.plot(x, cxMarks, marker='o')
plt.plot(x, cyMarks, marker='x')
plt.title("line chart")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# ### 03) WAP to generate line chart for given data, but create your custom axis.

# %%
x = range(1,11)
y = [1,5,9,7,5,6,3,2,4,9]

# %%
import matplotlib.pyplot as plt
x = range(1,11)
y = [1,5,9,7,5,6,3,2,4,9]
plt.axis([0 , 11, 0, 11])
plt.plot(x, y, marker='o')
plt.show()

# %% [markdown]
# ### 04) WAP to plot a line chart showing temperature variation during a week. Mark the lowest and highest temperatue.

# %%
Days = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
Temperature (°C) = [20, 32, 31, 33, 34, 43, 36]

# %%
import matplotlib.pyplot as plt
Days = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
Temperature = [20, 32, 31, 33, 34, 43, 36]
plt.annotate("Highest",xy=["Sat",43])
plt.annotate("Lowest",xy=["Mon",20])
plt.plot(Days, Temperature, marker='o')
plt.title("Temperature variation during a Week")
plt.xlabel("Days")
plt.ylabel("Temperature")
plt.show()

# %% [markdown]
# ### 05) WAP to create a detailed pie chart representing the monthly expenditure distribution of a family.
# ### The chart should display labels, percentage values, title, different colors for each slice, and explode one slice to highlight the highest expense.

# %%
Categories = ["Rent", "Food", "Education", "Transport", "Entertainment", "Savings"]
Amount (₹) = [15000, 8000, 6000, 3000, 2000, 5000]

# %%
import matplotlib.pyplot as plt

Categories = ["Rent", "Food", "Education", "Transport", "Entertainment", "Savings"]
Amount = [15000, 8000, 6000, 3000, 2000, 5000]

plt.pie(Amount, labels=Categories, autopct='%1.1f%%', startangle=90, explode = [0.1, 0, 0, 0, 0.1, 0])

plt.title("Monthly Family Expenditure Distribution")

plt.show()

# %% [markdown]
# ### 06) WAP to create bar chart showing the marks obtained by students in different subjects.
# ### The program should also display the marks on the top of the respective bar.

# %%
Subjects = ["Python", "DBMS", "SE", "PS", "PE-1"]
Marks = [78, 85, 72, 80, 90]

# %%
import matplotlib.pyplot as plt

Subjects = ["Python", "DBMS", "SE", "PS", "PE-1"]
Marks = [78, 85, 72, 80, 90]

bars = plt.bar(Subjects, Marks)

plt.bar_label(bars)

plt.title("Subjects and Marks")
plt.xlabel("Subjects")
plt.ylabel("Marks")

plt.show()

# %% [markdown]
# ### 07) WAP to create a horizontal bar chart representing the number of books sold in different categories.
# ### The program should also display the number of books sold at the end of the respective bar.

# %%
Categories = ["Fiction", "Science", "History", "Technology", "Biography"]
Books Sold = [120, 90, 70, 110, 60]

# %%
import matplotlib.pyplot as plt

Categories = ["Fiction", "Science", "History", "Technology", "Biography"]
Books_Sold = [120, 90, 70, 110, 60]

bars = plt.barh(Categories, Books_Sold)

plt.title("Number of books sold in different categories")
plt.xlabel("Categories")
plt.ylabel("Books Sold")

plt.bar_label(bars)
plt.show()

# %% [markdown]
# ### 08) WAP to create a scatter plot representing the relationship between advertising expenditure and sales revenue of a company.

# %%
Advertising Cost (₹ thousands) = [5, 8, 10, 12, 15, 18, 20]
Sales Revenue (₹ thousands) = [50, 60, 65, 70, 80, 90, 95]

# %%
import matplotlib.pyplot as plt

AdvertisingCost = [5, 8, 10, 12, 15, 18, 20]
SalesRevenue = [50, 60, 65, 70, 80, 90, 95]

plt.scatter(AdvertisingCost, SalesRevenue)

# %% [markdown]
# ### 09) WAP to create a histogram representing the distribution of marks obtained by students in a class.

# %%
Marks = [45, 50, 55, 60, 62, 65, 68, 70, 72, 75, 78, 80, 82, 85, 88, 90, 92, 95]

# %%
import matplotlib.pyplot as plt
marks = [45, 50, 55, 60, 62, 65, 68, 70, 72, 75, 78, 80, 82, 85, 88, 90, 92, 95]

plt.hist(marks, bins=6)

plt.xlabel("Marks Range")
plt.ylabel("Number of Students")
plt.title("Distribution of Students' Marks")

plt.show()

# %% [markdown]
# ### 10) WAP to create a box plot representing the distribution of daily commuting time (in minutes) of employees and identify outliers (if any).

# %%
Commuting Time (minutes) = [5, 18, 20, 22, 25, 27, 28, 30, 32, 35, 38, 40, 42, 90]

# %%
import matplotlib.pyplot as plt
CommutingTime = [5, 18, 20, 22, 25, 27, 28, 30, 32, 35, 38, 40, 42, 90]

plt.boxplot(CommutingTime)

plt.title("Daily Commuting Time (min)")
plt.ylabel("Time (minutes)")

plt.grid(True)

plt.show()
